# %%
# Import Dependencies
# %matplotlib inline

import json
import requests
import pandas as pd
import numpy as np
from config import api_key
from census import Census
import gmaps
import time
# from us import states

import matplotlib.pyplot as plt
import os
newList = []
filename = []

path = os.path.join('.')

# Read our Data file with the pandas library

# with os.scandir(path) as it:
#     for entry in it:
#         if entry.name.endswith(".csv") and entry.is_file():
#             filename.append(entry.name)

filename = ['1992_mod.csv'] #,'1993_mod.csv','1994_mod.csv']

for file in filename:
    data = pd.read_csv(file)
    data.columns = ['day', 'number_of_strikes', 'center_point', 'Day', 'Year', 'Month','Longitude', 'Latitude', 'LongitudeR', 'LatitudeR', 'Strikes']
    data.drop(columns = ['day','number_of_strikes'],axis=1,inplace=True)
    newList.append(data)

# %%
df = pd.concat(newList)
df.drop(columns = ['LongitudeR',"LatitudeR"],axis=1, inplace=True)

# %%
from census import Census
import gmaps
import time
from us import states

# %%
# Extract Latitude and Longitude from DataFrame
loc=data.center_point.str.extract('(-?\d*\.?\d?) (\d*\.?\d?)')  

# Add latitude and longitude information to original data. And convert the datatype.
data['Latitude']=loc[1].astype(float)
data['Longitude']=loc[0].astype(float)


# Extract unique locations
locates=loc.drop_duplicates()
locates.columns=['Longitude','Latitude']

lon=locates.iloc[0,0]
lat=locates.iloc[0,1]

locates
# Out:
#         Longitude Latitude
# 0           -96.2     31.5
# 1           -79.1     31.5
# 2           -78.9     30.5
# 3           -77.8     29.7
# 4           -77.6     29.9
# 5           -78.4     29.8
# 6           -91.8     28.8
# 7           -91.7     28.8
# 8           -95.6     26.8
# 9           -95.4     27.1
# 10          -90.1     29.2
# 11          -90.5       29
# 12          -89.5     29.5
# 13          -91.4     28.4
# 14          -89.9     29.4
# 15          -91.3     28.4
# 16          -88.2     30.2
# 17          -85.3     29.8
# 18          -88.3     30.2
# 19          -88.5     31.1
# 20          -89.2     29.7
# 21          -90.5     28.8
# 22          -88.4     30.2
# 23          -89.1     29.7
# 24          -89.4     29.6
# 25          -88.8     29.9
# 26          -90.2     29.1
# 27          -86.7     31.6
# 28          -84.7     29.2
# 29          -90.6     28.8
# ...           ...      ...
# 2459692    -119.6     46.9
# 2460718    -122.1     44.1
# 2464046    -118.5     46.7
# 2464295    -118.5     46.6
# 2470121     -70.4     42.6
# 2479204    -118.7     33.4
# 2480013    -116.8       36
# 2492277      -123     48.1
# 2492327    -122.8     45.8
# 2507432    -119.8     35.1
# 2512421    -122.8     39.9
# 2513237    -119.7     46.9
# 2526563    -113.8     28.6
# 2528967    -120.1     34.4
# 2529040      -120     34.6
# 2530276    -119.9       35
# 2534167     -71.1     44.1
# 2536231    -123.3     43.7
# 2536236    -123.3     43.5
# 2548554    -117.5     34.2
# 2549059    -118.6     33.3
# 2553680    -117.5       42
# 2554548    -119.3     41.5
# 2554896    -121.9     48.1
# 2559765    -157.8     63.6
# 2565675    -113.8     28.7
# 2571944    -122.3     39.3
# 2573052    -122.1     44.5
# 2604699    -118.6     46.1
# 2604755    -118.6     46.3
#
# [143816 rows x 2 columns]

# %%
# Extract addresses from GoogleAPI and store in a file
lens=locates.shape[0]
file1=open('locations.csv',"w")

for i in range(lens):
    try:
        lon=locates.iloc[i,0]
        lat=locates.iloc[i,1]
        url="https://maps.googleapis.com/maps/api/geocode/json?latlng="+lat+","+lon+"&key="+api_key
        info=requests.get(url).json()
        address=info['results'][0]["formatted_address"]
        print ("The latitude is "+lat+ " ;the longitude is "+ lon+ ";the address is "+ address+"\n")
        file1.write(lon+"\t"+lat+"\t"+address+"\n")
    except ValueError:
        next

file1.close()
# Out:
# The latitude is 31.5 ;the longitude is -96.2;the address is Rch Rd, Donie, TX 75838, USA
#
# The latitude is 31.5 ;the longitude is -79.1;the address is Atlantic Ocean
#
# The latitude is 30.5 ;the longitude is -78.9;the address is Atlantic Ocean
#
# The latitude is 29.7 ;the longitude is -77.8;the address is Atlantic Ocean
#
# The latitude is 29.9 ;the longitude is -77.6;the address is Atlantic Ocean
#
# The latitude is 29.8 ;the longitude is -78.4;the address is Atlantic Ocean
#
# The latitude is 28.8 ;the longitude is -91.8;the address is Gulf of Mexico
#
# The latitude is 28.8 ;the longitude is -91.7;the address is Gulf of Mexico
#
# The latitude is 26.8 ;the longitude is -95.6;the address is Gulf of Mexico
#
# The latitude is 27.1 ;the longitude is -95.4;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -90.1;the address is Golden Meadow, LA 70357, USA
#
# The latitude is 29 ;the longitude is -90.5;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -89.5;the address is 1, LA, USA
#
# The latitude is 28.4 ;the longitude is -91.4;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -89.9;the address is Port Sulphur, LA 70083, USA
#
# The latitude is 28.4 ;the longitude is -91.3;the address is Gulf of Mexico
#
# The latitude is 30.2 ;the longitude is -88.2;the address is Mobile County, AL, USA
#
# The latitude is 29.8 ;the longitude is -85.3;the address is 1601 Constitution Dr, Port St Joe, FL 32456, USA
#
# The latitude is 30.2 ;the longitude is -88.3;the address is Dauphin Island, AL, USA
#
# The latitude is 31.1 ;the longitude is -88.5;the address is 617 Beck Cave Rd, Lucedale, MS 39452, USA
#
# The latitude is 29.7 ;the longitude is -89.2;the address is E, LA, USA
#
# The latitude is 28.8 ;the longitude is -90.5;the address is Gulf of Mexico
#
# The latitude is 30.2 ;the longitude is -88.4;the address is Jackson County, MS, USA
#
# The latitude is 29.7 ;the longitude is -89.1;the address is Gulf of Mexico
#
# The latitude is 29.6 ;the longitude is -89.4;the address is 1, LA, USA
#
# The latitude is 29.9 ;the longitude is -88.8;the address is E, LA, USA
#
# The latitude is 29.1 ;the longitude is -90.2;the address is Unnamed Road, Golden Meadow, LA 70357, USA
#
# The latitude is 31.6 ;the longitude is -86.7;the address is 2596 Avant Loop, Georgiana, AL 36033, USA
#
# The latitude is 29.2 ;the longitude is -84.7;the address is Gulf of Mexico
#
# The latitude is 28.8 ;the longitude is -90.6;the address is Gulf of Mexico
#
# The latitude is 30.4 ;the longitude is -88.1;the address is 13901 AL-193, Coden, AL 36523, USA
#
# The latitude is 31.5 ;the longitude is -86.8;the address is Jones Chaple Rd, Evergreen, AL 36401, USA
#
# The latitude is 29 ;the longitude is -90.3;the address is Gulf of Mexico
#
# The latitude is 29.9 ;the longitude is -88.7;the address is Gulf of Mexico
#
# The latitude is 30.5 ;the longitude is -87.4;the address is Unnamed Road, Pensacola, FL 32526, USA
#
# The latitude is 30.4 ;the longitude is -88.2;the address is Rock Rd, Coden, AL 36523, USA
#
# The latitude is 29.9 ;the longitude is -85.4;the address is Gulf County, FL, USA
#
# The latitude is 29.6 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 30.3 ;the longitude is -88.1;the address is Dauphin Island, AL, USA
#
# The latitude is 30.1 ;the longitude is -88.6;the address is Gulf of Mexico
#
# The latitude is 30.3 ;the longitude is -87.9;the address is Baldwin County, AL, USA
#
# The latitude is 29.2 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 31.3 ;the longitude is -87.5;the address is 40 Elm St, Uriah, AL 36480, USA
#
# The latitude is 30.3 ;the longitude is -88;the address is Baldwin County, AL, USA
#
# The latitude is 29.3 ;the longitude is -86.5;the address is Gulf of Mexico
#
# The latitude is 30.5 ;the longitude is -87.3;the address is 7333 Mimosa Dr, Pensacola, FL 32526, USA
#
# The latitude is 29.4 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 30.5 ;the longitude is -87.6;the address is 24899 Douglas Ln, Summerdale, AL 36580, USA
#
# The latitude is 29.5 ;the longitude is -89.4;the address is 1, LA, USA
#
# The latitude is 29.5 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 31 ;the longitude is -88.6;the address is 420 Seldom Rest Rd, Lucedale, MS 39452, USA
#
# The latitude is 29.1 ;the longitude is -85.2;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 30 ;the longitude is -88.8;the address is E, LA, USA
#
# The latitude is 29.6 ;the longitude is -89.3;the address is 1, LA, USA
#
# The latitude is 29.9 ;the longitude is -85.3;the address is Unnamed Road, Port St Joe, FL 32456, USA
#
# The latitude is 31.6 ;the longitude is -86.6;the address is 3275 Cook Bridge Rd, Georgiana, AL 36033, USA
#
# The latitude is 29.8 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 29.7 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 28.7 ;the longitude is -85.5;the address is Gulf of Mexico
#
# The latitude is 29.1 ;the longitude is -90.1;the address is 9, LA, USA
#
# The latitude is 29.9 ;the longitude is -85.2;the address is Unnamed Road, Wewahitchka, FL 32465, USA
#
# The latitude is 31.5 ;the longitude is -86.7;the address is 35345 Lattice Loop, McKenzie, AL 36456, USA
#
# The latitude is 29.7 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 30 ;the longitude is -88.7;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -86.5;the address is Gulf of Mexico
#
# The latitude is 30.6 ;the longitude is -87.6;the address is Unnamed Road, Robertsdale, AL 36567, USA
#
# The latitude is 30.1 ;the longitude is -88.7;the address is Gulf of Mexico
#
# The latitude is 30.9 ;the longitude is -88.5;the address is 125 Munk Holliman Rd, Lucedale, MS 39452, USA
#
# The latitude is 30.9 ;the longitude is -88.9;the address is Unnamed Road, Wiggins, MS 39577, USA
#
# The latitude is 30.9 ;the longitude is -88.6;the address is 11203 Old Highway 63, Lucedale, MS 39452, USA
#
# The latitude is 30.2 ;the longitude is -88.5;the address is Jackson County, MS, USA
#
# The latitude is 30.8 ;the longitude is -87.4;the address is Unnamed Road, Molino, FL 32577, USA
#
# The latitude is 29.4 ;the longitude is -89.7;the address is 6, LA, USA
#
# The latitude is 29.5 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 30.5 ;the longitude is -87.7;the address is 728 NW 1st St, Summerdale, AL 36580, USA
#
# The latitude is 30.1 ;the longitude is -88.5;the address is Gulf of Mexico
#
# The latitude is 29.9 ;the longitude is -85.1;the address is 6153 Co Rd 387, Wewahitchka, FL 32465, USA
#
# The latitude is 31.4 ;the longitude is -87;the address is 383 Turner Rd, Evergreen, AL 36401, USA
#
# The latitude is 29.3 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 28.6 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -89.9;the address is Parish Governing Authority District 1, LA, USA
#
# The latitude is 29.8 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -89.3;the address is 1, LA, USA
#
# The latitude is 30.1 ;the longitude is -88.4;the address is Gulf of Mexico
#
# The latitude is 30.1 ;the longitude is -88.3;the address is Gulf of Mexico
#
# The latitude is 29.8 ;the longitude is -85.5;the address is Gulf of Mexico
#
# The latitude is 30.3 ;the longitude is -88.4;the address is Jackson County, MS, USA
#
# The latitude is 30.3 ;the longitude is -88.2;the address is Dauphin Island, AL, USA
#
# The latitude is 30.6 ;the longitude is -87.3;the address is 990 El Camino Dr, Cantonment, FL 32533, USA
#
# The latitude is 30.3 ;the longitude is -88.3;the address is Dauphin Island, AL, USA
#
# The latitude is 30.5 ;the longitude is -88;the address is Baldwin County, AL, USA
#
# The latitude is 29.6 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 30 ;the longitude is -88.5;the address is Gulf of Mexico
#
# The latitude is 29.8 ;the longitude is -89.1;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -89.8;the address is 6, LA, USA
#
# The latitude is 30 ;the longitude is -88.6;the address is Gulf of Mexico
# The latitude is 28.5 ;the longitude is -82.1;the address is 38471 Richloam Clay Sink Rd, Webster, FL 33597, USA
#
# The latitude is 31.1 ;the longitude is -82.3;the address is Unnamed Road, Waycross, GA 31503, USA
#
# The latitude is 31.1 ;the longitude is -78.5;the address is Atlantic Ocean
#
# The latitude is 31.1 ;the longitude is -78.4;the address is Atlantic Ocean
#
# The latitude is 31.1 ;the longitude is -82.1;the address is 7891 Randall Crews Rd, Hoboken, GA 31542, USA
#
# The latitude is 25.7 ;the longitude is -85;the address is Gulf of Mexico
#
# The latitude is 26 ;the longitude is -84.4;the address is Gulf of Mexico
#
# The latitude is 28.6 ;the longitude is -99.7;the address is FM 65, Crystal City, TX 78839, USA
#
# The latitude is 29.8 ;the longitude is -98.8;the address is 10242 Johns Rd, Boerne, TX 78006, USA
#
# The latitude is 28.4 ;the longitude is -99.8;the address is Asherton, TX 78827, USA
#
# The latitude is 27.3 ;the longitude is -96;the address is Gulf of Mexico
#
# The latitude is 27.7 ;the longitude is -95.4;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -95.7;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -95.6;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -95.8;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -95.9;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -95.9;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -95.7;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -95.9;the address is Gulf of Mexico
#
# The latitude is 27.2 ;the longitude is -98.3;the address is Unnamed Road, Falfurrias, TX 78355, USA
#
# The latitude is 26.8 ;the longitude is -98.2;the address is Unnamed Road, Encino, TX 78353, USA
#
# The latitude is 27.2 ;the longitude is -98.4;the address is Unnamed Road, Falfurrias, TX 78355, USA
#
# The latitude is 27.8 ;the longitude is -98;the address is Alice, TX 78332, USA
#
# The latitude is 28.9 ;the longitude is -92.1;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -95.8;the address is Gulf of Mexico
#
# The latitude is 28.6 ;the longitude is -92.6;the address is Gulf of Mexico
#
# The latitude is 27.7 ;the longitude is -95.1;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -95.7;the address is Gulf of Mexico
#
# The latitude is 28.8 ;the longitude is -92.5;the address is Gulf of Mexico
#
# The latitude is 28.5 ;the longitude is -98.6;the address is Unnamed Road, Tilden, TX 78072, USA
#
# The latitude is 28.7 ;the longitude is -92.6;the address is Gulf of Mexico
#
# The latitude is 27.1 ;the longitude is -94.3;the address is Gulf of Mexico
#
# The latitude is 26.8 ;the longitude is -98.3;the address is Unnamed Road, Encino, TX 78353, USA
#
# The latitude is 27.5 ;the longitude is -98.3;the address is Co Rd 213, Concepcion, TX 78349, USA
#
# The latitude is 27.6 ;the longitude is -95.2;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -98.2;the address is 3245 FM 2295, Alice, TX 78332, USA
#
# The latitude is 28.4 ;the longitude is -92.7;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -95.6;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -95.4;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -95.8;the address is Gulf of Mexico
#
# The latitude is 27.8 ;the longitude is -95.3;the address is Gulf of Mexico
#
# The latitude is 27.7 ;the longitude is -95.3;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -96;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -95.5;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -95.1;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -96.1;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -95.9;the address is Gulf of Mexico
#
# The latitude is 28.9 ;the longitude is -92.4;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -95.8;the address is Gulf of Mexico
#
# The latitude is 27.2 ;the longitude is -94.2;the address is Gulf of Mexico
#
# The latitude is 27.2 ;the longitude is -96.1;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -96;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -95.5;the address is Gulf of Mexico
#
# The latitude is 27.9 ;the longitude is -95.2;the address is Gulf of Mexico
#
# The latitude is 29 ;the longitude is -92.1;the address is Gulf of Mexico
#
# The latitude is 28.7 ;the longitude is -92.5;the address is Gulf of Mexico
#
# The latitude is 27.2 ;the longitude is -95.9;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -98.2;the address is Co Rd 425, Premont, TX 78375, USA
#
# The latitude is 27.6 ;the longitude is -95.7;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -98.2;the address is Co Rd 425, Premont, TX 78375, USA
#
# The latitude is 27.8 ;the longitude is -95.1;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -95.6;the address is Gulf of Mexico
#
# The latitude is 28.5 ;the longitude is -92.6;the address is Gulf of Mexico
#
# The latitude is 26.5 ;the longitude is -80.5;the address is Unnamed Road, Belle Glade, FL 33430, USA
#
# The latitude is 25.6 ;the longitude is -81.6;the address is Gulf of Mexico
#
# The latitude is 25.3 ;the longitude is -81.3;the address is Gulf of Mexico
#
# The latitude is 28.8 ;the longitude is -81.4;the address is 8050 Peaceful Cir, Sanford, FL 32771, USA
#
# The latitude is 25 ;the longitude is -81.8;the address is Gulf of Mexico
#
# The latitude is 26 ;the longitude is -79.7;the address is Atlantic Ocean
#
# The latitude is 24.9 ;the longitude is -83.1;the address is Gulf of Mexico
#
# The latitude is 25.1 ;the longitude is -81.7;the address is Gulf of Mexico
#
# The latitude is 24.7 ;the longitude is -83.4;the address is Gulf of Mexico
#
# The latitude is 25.2 ;the longitude is -81.4;the address is Gulf of Mexico
#
# The latitude is 25.6 ;the longitude is -79.3;the address is The Bahamas
#
# The latitude is 24.9 ;the longitude is -83.2;the address is Gulf of Mexico
#
# The latitude is 29 ;the longitude is -80.5;the address is United States
#
# The latitude is 32.9 ;the longitude is -76.2;the address is Atlantic Ocean
#
# The latitude is 32.9 ;the longitude is -76.3;the address is Atlantic Ocean
#
# The latitude is 35 ;the longitude is -97.5;the address is 19093 OK-24, Purcell, OK 73080, USA
#
# The latitude is 34.4 ;the longitude is -96.5;the address is 3687 Ok Hwy 7d, Bromide, OK 74530, USA
#
# The latitude is 34.9 ;the longitude is -97.5;the address is 22741 OK-59, Lindsay, OK 73052, USA
#
# The latitude is 33.8 ;the longitude is -97.5;the address is Rock Bluff Rd, St Jo, TX 76265, USA
#
# The latitude is 34.1 ;the longitude is -96;the address is 755 Wilson N Jones Rd, Bennington, OK 74723, USA
#
# The latitude is 34.4 ;the longitude is -97.6;the address is Pinto Rd, Healdton, OK 73438, USA
#
# The latitude is 29.1 ;the longitude is -96.9;the address is Unnamed Road, Yoakum, TX 77995, USA
#
# The latitude is 34.4 ;the longitude is -96.4;the address is Unnamed Road, Wapanucka, OK 73461, USA
#
# The latitude is 34.3 ;the longitude is -96.8;the address is Burch Rd, Mill Creek, OK 74856, USA
#
# The latitude is 34.1 ;the longitude is -95.2;the address is Unnamed Road, Fort Towson, OK 74735, USA
#
# The latitude is 34.4 ;the longitude is -97.5;the address is 23250 Oklahoma 76, Ratliff City, OK 73481, USA
#
# The latitude is 34.1 ;the longitude is -97.2;the address is Ardmore, OK 73401, USA
#
# The latitude is 34.4 ;the longitude is -96.3;the address is 260 Standing Rock Rd, Atoka, OK 74525, USA
#
# The latitude is 34.5 ;the longitude is -97.6;the address is N3030 Rd, Tussy, OK 73488, USA
#
# The latitude is 34.1 ;the longitude is -97.6;the address is 12999 N 3030 Rd, Ringling, OK 73456, USA
#
# The latitude is 34.4 ;the longitude is -96.6;the address is Milburn, OK 73450, USA
#
# The latitude is 34.2 ;the longitude is -97;the address is 186 Waterford Dr, Ardmore, OK 73401, USA
#
# The latitude is 34.1 ;the longitude is -97.4;the address is E2010 Rd, Wilson, OK 73463, USA
#
# The latitude is 33.8 ;the longitude is -97.6;the address is FM1956, St Jo, TX 76265, USA
#
# The latitude is 34.2 ;the longitude is -96.9;the address is 3070 Union Rd, Mannsville, OK 73447, USA
# The latitude is 35.2 ;the longitude is -97.5;the address is 4887 Broad Acres Rd, Norman, OK 73072, USA
#
# The latitude is 34.8 ;the longitude is -97.5;the address is Lindsay, OK 73052, USA
#
# The latitude is 34.3 ;the longitude is -97.6;the address is 187237 OK-89, Loco, OK 73442, USA
#
# The latitude is 33.6 ;the longitude is -97.8;the address is 4657 TX-59, Bowie, TX 76230, USA
#
# The latitude is 34.3 ;the longitude is -96.7;the address is Unnamed Road, Tishomingo, OK 73460, USA
#
# The latitude is 34.3 ;the longitude is -96.9;the address is Mannsville, OK 73447, USA
#
# The latitude is 34.3 ;the longitude is -97;the address is 1 Riverside Rd, Ardmore, OK 73401, USA
#
# The latitude is 35.3 ;the longitude is -97.4;the address is 17301 Chatham Hills Rd, Norman, OK 73071, USA
#
# The latitude is 33.7 ;the longitude is -97.6;the address is Thompson Rd, St Jo, TX 76265, USA
#
# The latitude is 34 ;the longitude is -97.7;the address is Grady, OK 73569, USA
#
# The latitude is 35.3 ;the longitude is -97.5;the address is 4109 Olde Pond Ct, Moore, OK 73160, USA
#
# The latitude is 34 ;the longitude is -97.6;the address is OK-32, Ringling, OK 73456, USA
#
# The latitude is 34.5 ;the longitude is -97.5;the address is Unnamed Road, Ratliff City, OK 73481, USA
#
# The latitude is 34.2 ;the longitude is -97.6;the address is OK-89, Ringling, OK 73456, USA
#
# The latitude is 34.2 ;the longitude is -97.1;the address is 1801 Quail Rd, Ardmore, OK 73401, USA
#
# The latitude is 33.9 ;the longitude is -97.6;the address is FM2953, St Jo, TX 76265, USA
#
# The latitude is 34.3 ;the longitude is -96.6;the address is 2698 E Dairy Ln, Tishomingo, OK 73460, USA
#
# The latitude is 35.4 ;the longitude is -97.4;the address is Oklahoma City, OK 73135, USA
#
# The latitude is 34.5 ;the longitude is -96.3;the address is N3770 Rd, Coalgate, OK 74538, USA
#
# The latitude is 35.1 ;the longitude is -97.5;the address is 26879 Cypress Ln, Washington, OK 73093, USA
#
# The latitude is 32.8 ;the longitude is -93.9;the address is 11874 Raines School Rd, Vivian, LA 71082, USA
#
# The latitude is 32.9 ;the longitude is -94.5;the address is Co Rd 1649, Jefferson, TX 75657, USA
#
# The latitude is 32.7 ;the longitude is -94.5;the address is Beaty Rd, Jefferson, TX 75657, USA
#
# The latitude is 32.9 ;the longitude is -92.7;the address is Unnamed Road, Bernice, LA 71222, USA
#
# The latitude is 32.7 ;the longitude is -94.8;the address is 1594 FM 726, Gilmer, TX 75645, USA
#
# The latitude is 33 ;the longitude is -95.3;the address is 1101 Co Rd 3270, Winnsboro, TX 75494, USA
#
# The latitude is 32.7 ;the longitude is -93.5;the address is 801 Bodcau Dam Rd, Haughton, LA 71037, USA
#
# The latitude is 32.9 ;the longitude is -95.5;the address is 5827 FM 515, Yantis, TX 75497, USA
#
# The latitude is 33.1 ;the longitude is -95.3;the address is FM 900, Saltillo, TX 75478, USA
#
# The latitude is 32.7 ;the longitude is -94.9;the address is 1961 Skylark Rd, Gilmer, TX 75645, USA
#
# The latitude is 32.7 ;the longitude is -94.7;the address is Davidson Rd, Diana, TX 75640, USA
#
# The latitude is 32.7 ;the longitude is -94.6;the address is Coppedge Smith Rd, Harleton, TX 75651, USA
#
# The latitude is 32.7 ;the longitude is -94.3;the address is 3531 Black Jack Rd, Jefferson, TX 75657, USA
#
# The latitude is 32.8 ;the longitude is -93.4;the address is 526 Magnolia Camp Rd, Cotton Valley, LA 71018, USA
#
# The latitude is 32.8 ;the longitude is -93.5;the address is Benton, LA 71006, USA
#
# The latitude is 32.8 ;the longitude is -93.8;the address is Cavett River Rd, Belcher, LA 71004, USA
#
# The latitude is 32.8 ;the longitude is -93.3;the address is 7955 Dorcheat Rd, Minden, LA 71055, USA
#
# The latitude is 32.7 ;the longitude is -96.6;the address is 905 Quietwood Dr, Dallas, TX 75253, USA
#
# The latitude is 32.8 ;the longitude is -96.5;the address is Unnamed Road, Sunnyvale, TX 75182, USA
#
# The latitude is 32.9 ;the longitude is -92.8;the address is 155 Marvin Ln, Bernice, LA 71222, USA
#
# The latitude is 32.9 ;the longitude is -92.6;the address is 923 Barnes Bridge Rd, Spearsville, LA 71277, USA
#
# The latitude is 32.8 ;the longitude is -93.2;the address is 450 Line Rd, Homer, LA 71040, USA
#
# The latitude is 31.9 ;the longitude is -94;the address is Forest Service Rd 137, Joaquin, TX 75954, USA
#
# The latitude is 38.9 ;the longitude is -88.8;the address is County Rd 2400 E, Farina, IL 62838, USA
#
# The latitude is 31.3 ;the longitude is -89.8;the address is Columbia, MS 39429, USA
#
# The latitude is 39.1 ;the longitude is -88.5;the address is 12691 1650th St, Teutopolis, IL 62467, USA
#
# The latitude is 38.9 ;the longitude is -88.9;the address is County Rd 1100 N, St Peter, IL 62880, USA
#
# The latitude is 30.1 ;the longitude is -91.4;the address is 4, LA, USA
#
# The latitude is 30.5 ;the longitude is -92.1;the address is 410 Beverly Rd, Opelousas, LA 70570, USA
#
# The latitude is 31.4 ;the longitude is -86.8;the address is 86 Bledsoe Dr, Evergreen, AL 36401, USA
#
# The latitude is 30.5 ;the longitude is -92.2;the address is 2375 LA-752, Opelousas, LA 70570, USA
#
# The latitude is 39 ;the longitude is -88.8;the address is 255 County Rd 600 N, St Elmo, IL 62458, USA
#
# The latitude is 27.6 ;the longitude is -84.5;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -84.3;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -84.4;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -92;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -88.7;the address is Gulf of Mexico
#
# The latitude is 29.9 ;the longitude is -90.1;the address is 611 Barataria Blvd, Marrero, LA 70072, USA
#
# The latitude is 30 ;the longitude is -90;the address is 7500 Terminal Rd, New Orleans, LA 70126, USA
#
# The latitude is 30.7 ;the longitude is -88.3;the address is 426 Paget Drive West, Mobile, AL 36608, USA
#
# The latitude is 29.8 ;the longitude is -90.4;the address is Bayou Gauche, LA, USA
#
# The latitude is 28.5 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.2;the address is Gulf of Mexico
#
# The latitude is 30.1 ;the longitude is -89.1;the address is Gulf of Mexico
#
# The latitude is 29.8 ;the longitude is -90.1;the address is Leo Kerner Pkwy, Marrero, LA 70072, USA
#
# The latitude is 28.3 ;the longitude is -86.5;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -87.2;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -92.3;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -93;the address is Gulf of Mexico
#
# The latitude is 30.1 ;the longitude is -89.8;the address is Lake Catherine, New Orleans, LA, USA
#
# The latitude is 29.6 ;the longitude is -91.4;the address is Patterson, LA 70392, USA
#
# The latitude is 30.1 ;the longitude is -89.3;the address is E, LA, USA
#
# The latitude is 29.5 ;the longitude is -91.4;the address is 4, LA, USA
#
# The latitude is 30.1 ;the longitude is -85.1;the address is National Forest Rd 115, Bristol, FL 32321, USA
#
# The latitude is 29 ;the longitude is -92.5;the address is Gulf of Mexico
#
# The latitude is 29.9 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 30.4 ;the longitude is -87.5;the address is 30991 Hagendorfer Rd, Lillian, AL 36549, USA
#
# The latitude is 28.2 ;the longitude is -87;the address is Gulf of Mexico
#
# The latitude is 28.7 ;the longitude is -87.1;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.8;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.6;the address is Gulf of Mexico
#
# The latitude is 29.7 ;the longitude is -91.3;the address is 115 Landry St, Patterson, LA 70392, USA
#
# The latitude is 29.2 ;the longitude is -92.5;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.5;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -92;the address is 10, LA, USA
#
# The latitude is 30.7 ;the longitude is -88.2;the address is 5928 S Westhaven Dr, Mobile, AL 36608, USA
#
# The latitude is 28 ;the longitude is -86.5;the address is Gulf of Mexico
#
# The latitude is 29.9 ;the longitude is -90.3;the address is 2, LA, USA
#
# The latitude is 29.6 ;the longitude is -91.6;the address is 3, LA, USA
#
# The latitude is 30.1 ;the longitude is -89.4;the address is E, LA, USA
# The latitude is 29.5 ;the longitude is -91.8;the address is 10, LA, USA
#
# The latitude is 28.6 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 30 ;the longitude is -89.9;the address is New Orleans, LA 70129, USA
#
# The latitude is 28.4 ;the longitude is -87.3;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.1;the address is Gulf of Mexico
#
# The latitude is 30.7 ;the longitude is -88.5;the address is 24521 Ramie Farm Rd, Lucedale, MS 39452, USA
#
# The latitude is 28.4 ;the longitude is -86.8;the address is Gulf of Mexico
#
# The latitude is 30.2 ;the longitude is -89.7;the address is 53716 US-90, Slidell, LA 70461, USA
#
# The latitude is 30.8 ;the longitude is -87.2;the address is 9964 Chumuckla Hwy, Jay, FL 32565, USA
#
# The latitude is 30.5 ;the longitude is -88.7;the address is 5511 C L Dees Dr, Vancleave, MS 39565, USA
#
# The latitude is 29.6 ;the longitude is -90.7;the address is 2008 Rhonda Annette Ct, Houma, LA 70363, USA
#
# The latitude is 29.3 ;the longitude is -91.9;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -86.5;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -92.2;the address is Gulf of Mexico
#
# The latitude is 29.8 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 28.5 ;the longitude is -87.2;the address is Gulf of Mexico
#
# The latitude is 30.1 ;the longitude is -90;the address is Orleans Parish, New Orleans, LA, USA
#
# The latitude is 28.3 ;the longitude is -87.4;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -91.7;the address is 10, LA, USA
#
# The latitude is 30.1 ;the longitude is -89.2;the address is E, LA, USA
#
# The latitude is 29.6 ;the longitude is -92.1;the address is 9, LA, USA
#
# The latitude is 29.9 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -87.1;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.7;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 29.6 ;the longitude is -91.9;the address is 10, LA, USA
#
# The latitude is 28.2 ;the longitude is -87.4;the address is Gulf of Mexico
#
# The latitude is 29.6 ;the longitude is -91.8;the address is 10, LA, USA
#
# The latitude is 30.7 ;the longitude is -88.6;the address is Unnamed Road, Lucedale, MS 39452, USA
#
# The latitude is 30.8 ;the longitude is -88.2;the address is 4998 Indian Springs Dr, Eight Mile, AL 36613, USA
#
# The latitude is 29.7 ;the longitude is -91.1;the address is 4099 Lake Palourde Rd, Morgan City, LA 70380, USA
#
# The latitude is 29.3 ;the longitude is -91.8;the address is Gulf of Mexico
#
# The latitude is 29 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 29.9 ;the longitude is -90.2;the address is Unnamed Road, Avondale, LA 70094, USA
#
# The latitude is 29.7 ;the longitude is -90.2;the address is Barataria, LA 70036, USA
#
# The latitude is 28.5 ;the longitude is -86.9;the address is Gulf of Mexico
#
# The latitude is 30.3 ;the longitude is -89.1;the address is Harrison County, MS, USA
#
# The latitude is 30 ;the longitude is -89.6;the address is E, LA, USA
#
# The latitude is 29.1 ;the longitude is -93.1;the address is Gulf of Mexico
#
# The latitude is 30.1 ;the longitude is -89.7;the address is Lake Catherine, New Orleans, LA, USA
#
# The latitude is 28.9 ;the longitude is -86.8;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -92.1;the address is Gulf of Mexico
#
# The latitude is 29.8 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -92.6;the address is Gulf of Mexico
#
# The latitude is 29.7 ;the longitude is -91.2;the address is 1230 Victor II Blvd, Morgan City, LA 70380, USA
#
# The latitude is 29.6 ;the longitude is -91.3;the address is Patterson, LA 70392, USA
#
# The latitude is 29.2 ;the longitude is -86.9;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -86.9;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -92.5;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -91.3;the address is 4, LA, USA
#
# The latitude is 29.4 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 30.2 ;the longitude is -89.2;the address is E, LA, USA
#
# The latitude is 29.4 ;the longitude is -91.8;the address is 10, LA, USA
#
# The latitude is 29.7 ;the longitude is -91;the address is 610 Cypress St, Gibson, LA 70356, USA
#
# The latitude is 28.6 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -86.8;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 30.3 ;the longitude is -89.3;the address is 200 Lovers Ln, Pass Christian, MS 39571, USA
#
# The latitude is 29.2 ;the longitude is -92.7;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -92.1;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -93;the address is Gulf of Mexico
#
# The latitude is 28.7 ;the longitude is -92.9;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -88.8;the address is Gulf of Mexico
#
# The latitude is 28.6 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 29.7 ;the longitude is -90.3;the address is 4, LA, USA
#
# The latitude is 28.2 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 29.6 ;the longitude is -92;the address is 10, LA, USA
#
# The latitude is 28 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 29 ;the longitude is -91.5;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.4;the address is Gulf of Mexico
#
# The latitude is 30.1 ;the longitude is -89.5;the address is E, LA, USA
#
# The latitude is 29.8 ;the longitude is -90.3;the address is Luling, LA 70070, USA
#
# The latitude is 28.5 ;the longitude is -86.8;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -92.4;the address is Gulf of Mexico
#
# The latitude is 29.1 ;the longitude is -91.5;the address is Gulf of Mexico
#
# The latitude is 30.1 ;the longitude is -89.6;the address is E, LA, USA
#
# The latitude is 29.8 ;the longitude is -90.9;the address is Forty Arpent Rd, Thibodaux, LA 70301, USA
#
# The latitude is 28.9 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.3;the address is Gulf of Mexico
#
# The latitude is 30.7 ;the longitude is -88.4;the address is 931 Cemetery Rd, Wilmer, AL 36587, USA
#
# The latitude is 28.6 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -86.8;the address is Gulf of Mexico
#
# The latitude is 30 ;the longitude is -89.4;the address is E, LA, USA
#
# The latitude is 28.5 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -92.3;the address is 9, LA, USA
#
# The latitude is 29.9 ;the longitude is -90;the address is 5301 Tullis Dr, New Orleans, LA 70131, USA
#
# The latitude is 28.4 ;the longitude is -86.5;the address is Gulf of Mexico
#
# The latitude is 30 ;the longitude is -85.3;the address is Unnamed Road, Wewahitchka, FL 32465, USA
#
# The latitude is 28.7 ;the longitude is -93;the address is Gulf of Mexico
#
# The latitude is 29.8 ;the longitude is -85.4;the address is Cabin Rd, Port St Joe, FL 32456, USA
#
# The latitude is 29.5 ;the longitude is -92.2;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -87;the address is Gulf of Mexico
#
# The latitude is 30.2 ;the longitude is -89.3;the address is Harrison County, MS, USA
#
# The latitude is 30.2 ;the longitude is -89.4;the address is Hancock County, MS, USA
#
# The latitude is 28.4 ;the longitude is -86.3;the address is Gulf of Mexico
# The latitude is 28.5 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 30.4 ;the longitude is -89;the address is 2771 Pass Rd, Biloxi, MS 39531, USA
#
# The latitude is 30 ;the longitude is -89.8;the address is E, LA, USA
#
# The latitude is 28.8 ;the longitude is -92.9;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -92.9;the address is Gulf of Mexico
#
# The latitude is 30.3 ;the longitude is -89.2;the address is Harrison County, MS, USA
#
# The latitude is 29.9 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 29.1 ;the longitude is -92.2;the address is Gulf of Mexico
#
# The latitude is 29.6 ;the longitude is -91.7;the address is 10, LA, USA
#
# The latitude is 30 ;the longitude is -89.7;the address is E, LA, USA
#
# The latitude is 28.5 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -92.8;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -91.7;the address is 10, LA, USA
#
# The latitude is 29.5 ;the longitude is -92.1;the address is Gulf of Mexico
#
# The latitude is 29.8 ;the longitude is -90.2;the address is 4, LA, USA
#
# The latitude is 28.9 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 29.1 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -91.5;the address is 4, LA, USA
#
# The latitude is 29.5 ;the longitude is -91.9;the address is 10, LA, USA
#
# The latitude is 28 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 30.1 ;the longitude is -88.9;the address is E, LA, USA
#
# The latitude is 30.1 ;the longitude is -89.9;the address is I-10, New Orleans, LA 70129, USA
#
# The latitude is 29.4 ;the longitude is -91.9;the address is 10, LA, USA
#
# The latitude is 30 ;the longitude is -85.5;the address is FL-30, Panama City, FL 32403, USA
#
# The latitude is 28 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 29.8 ;the longitude is -91;the address is 4, LA, USA
#
# The latitude is 28.1 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 29.9 ;the longitude is -90.7;the address is Chackbay, LA 70301, USA
#
# The latitude is 29.5 ;the longitude is -91.6;the address is 10, LA, USA
#
# The latitude is 29.6 ;the longitude is -90.6;the address is 510 Lake Long Dr, Houma, LA 70364, USA
#
# The latitude is 28.3 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 30.4 ;the longitude is -89.1;the address is 15439 W Adams St, Gulfport, MS 39501, USA
#
# The latitude is 29.4 ;the longitude is -92;the address is Gulf of Mexico
#
# The latitude is 29.6 ;the longitude is -91.1;the address is Berwick, LA 70342, USA
#
# The latitude is 30 ;the longitude is -85.4;the address is 44 Th St, Port St Joe, FL 32456, USA
#
# The latitude is 28.6 ;the longitude is -87.3;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -87.6;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -87.4;the address is Gulf of Mexico
#
# The latitude is 29.2 ;the longitude is -93.1;the address is Gulf of Mexico
#
# The latitude is 28.5 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 30 ;the longitude is -90.1;the address is 6100 Marconi Dr, New Orleans, LA 70124, USA
#
# The latitude is 28.1 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -86.5;the address is Gulf of Mexico
#
# The latitude is 29 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 29.3 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -87.1;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 28.6 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 29.7 ;the longitude is -91.7;the address is 3, LA, USA
#
# The latitude is 28.3 ;the longitude is -87;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -92.4;the address is Gulf of Mexico
#
# The latitude is 29 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 30 ;the longitude is -89.3;the address is E, LA, USA
#
# The latitude is 28.9 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 27.9 ;the longitude is -86.6;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 28 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 28.6 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 27.8 ;the longitude is -84.9;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 28 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 28.7 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 28 ;the longitude is -86.8;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 27.9 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 28 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 28.8 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 29.5 ;the longitude is -88.4;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 29.4 ;the longitude is -88.7;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 28.5 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 27.1 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 27.9 ;the longitude is -87;the address is Gulf of Mexico
#
# The latitude is 27.7 ;the longitude is -85.2;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 28.5 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 27.7 ;the longitude is -85.5;the address is Gulf of Mexico
#
# The latitude is 28.6 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 28 ;the longitude is -86;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -90.4;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -85.4;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 27.3 ;the longitude is -86;the address is Gulf of Mexico
# The latitude is 27.5 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 28.5 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 28.2 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 27.8 ;the longitude is -86.7;the address is Gulf of Mexico
#
# The latitude is 27.7 ;the longitude is -85.4;the address is Gulf of Mexico
#
# The latitude is 28.4 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 28.8 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -86.4;the address is Gulf of Mexico
#
# The latitude is 28.1 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 27.7 ;the longitude is -85.3;the address is Gulf of Mexico
#
# The latitude is 28.8 ;the longitude is -86.1;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -85.5;the address is Gulf of Mexico
#
# The latitude is 28.7 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 28 ;the longitude is -91.1;the address is Gulf of Mexico
#
# The latitude is 28.5 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 27.6 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 27.5 ;the longitude is -85.7;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -86.3;the address is Gulf of Mexico
#
# The latitude is 28.6 ;the longitude is -85.8;the address is Gulf of Mexico
#
# The latitude is 28.3 ;the longitude is -85.6;the address is Gulf of Mexico
#
# The latitude is 27.4 ;the longitude is -86.2;the address is Gulf of Mexico
#
# The latitude is 28 ;the longitude is -85.9;the address is Gulf of Mexico
#
# The latitude is 31.5 ;the longitude is -77.8;the address is Atlantic Ocean
#
# The latitude is 28.1 ;the longitude is -80.1;the address is United States
#
# The latitude is 32.2 ;the longitude is -97.1;the address is 155 Pr 446 Sh 66, Itasca, TX 76055, USA
#
# The latitude is 30.3 ;the longitude is -101;the address is Ozona, TX 76943, USA
#
# The latitude is 29.1 ;the longitude is -99.4;the address is Unnamed Road, Pearsall, TX 78061, USA
#
# The latitude is 31.8 ;the longitude is -100;the address is Ballinger, TX 76821, USA
#
# The latitude is 30.8 ;the longitude is -96.6;the address is 4389 FM 50, Hearne, TX 77859, USA
#
# The latitude is 32.2 ;the longitude is -97;the address is Unnamed Road, Milford, TX 76670, USA
#
# The latitude is 29 ;the longitude is -99.6;the address is Unnamed Road, Batesville, TX 78829, USA
#
# The latitude is 30.1 ;the longitude is -94.6;the address is Unnamed Road, Devers, TX 77538, USA
#
# The latitude is 29.5 ;the longitude is -96.1;the address is Co Rd 205, East Bernard, TX 77435, USA
#
# The latitude is 30.3 ;the longitude is -101.6;the address is Unnamed Road, Ozona, TX 76943, USA
#
# The latitude is 28.9 ;the longitude is -100.1;the address is Unnamed Road, Texas, USA
#
# The latitude is 30 ;the longitude is -97.5;the address is 929 Co Rd 221, Cedar Creek, TX 78612, USA
#
# The latitude is 29.6 ;the longitude is -96.5;the address is Columbus, TX 78934, USA
#
# The latitude is 29.3 ;the longitude is -96.2;the address is FM 961 Rd, Wharton, TX 77488, USA
#
# The latitude is 32 ;the longitude is -99.9;the address is 324 Co Rd 202, Winters, TX 79567, USA
#
# The latitude is 32.1 ;the longitude is -99.8;the address is Unnamed Road, Lawn, TX 79530, USA
#
# The latitude is 30.1 ;the longitude is -94.7;the address is Unnamed Road, Liberty, TX 77575, USA
#
# The latitude is 29.7 ;the longitude is -98.1;the address is 930 Pine St, New Braunfels, TX 78130, USA
#
# The latitude is 30.4 ;the longitude is -96.9;the address is Co Rd 402, Dime Box, TX 77853, USA
#
# The latitude is 29.5 ;the longitude is -95.9;the address is Happy Landings Airport-2H5, 7811 Dashwood Dr, Houston, TX 77036, USA
#
# The latitude is 29.4 ;the longitude is -96.2;the address is Unnamed Road, Wharton, TX 77488, USA
#
# The latitude is 29.1 ;the longitude is -97;the address is 682 16419 Fm, Yoakum, TX 77995, USA
#
# The latitude is 31.8 ;the longitude is -100.1;the address is Pvt Rd 2801, Ballinger, TX 76821, USA
#
# The latitude is 29.7 ;the longitude is -98.2;the address is 978 Woodland Oaks, New Braunfels, TX 78132, USA
#
# The latitude is 30.1 ;the longitude is -97.5;the address is 174 Jenkins Rd, Cedar Creek, TX 78612, USA
#
# The latitude is 30.5 ;the longitude is -96.7;the address is 1149 Co Rd 106, Caldwell, TX 77836, USA
#
# The latitude is 29.7 ;the longitude is -95.6;the address is 12463 Sharpview Dr, Houston, TX 77072, USA
#
# The latitude is 30.6 ;the longitude is -96.4;the address is 8423 TX-47, Bryan, TX 77807, USA
#
# The latitude is 27.2 ;the longitude is -93.7;the address is Gulf of Mexico
#
# The latitude is 30.3 ;the longitude is -101.3;the address is Unnamed Road, Ozona, TX 76943, USA
#
# The latitude is 29.6 ;the longitude is -96.1;the address is Co Rd 293, East Bernard, TX 77435, USA
#
# The latitude is 29 ;the longitude is -97.9;the address is County Rd 253, Hobson, TX 78117, USA
#
# The latitude is 28.9 ;the longitude is -100.3;the address is Unnamed Road, Eagle Pass, TX 78852, USA
#
# The latitude is 29.7 ;the longitude is -95.5;the address is 6630 Roos Rd, Houston, TX 77074, USA
#
# The latitude is 29.6 ;the longitude is -98.3;the address is 17269 Lookout Rd, Selma, TX 78154, USA
#
# The latitude is 29.8 ;the longitude is -95.7;the address is 18993 Saums Rd, Houston, TX 77084, USA
#
# The latitude is 29.4 ;the longitude is -96.8;the address is Hallettsville, TX 77964, USA
#
# The latitude is 29.4 ;the longitude is -99;the address is 628 Co Rd 4512, Hondo, TX 78861, USA
#
# The latitude is 28.8 ;the longitude is -98.4;the address is Unnamed Road, Pleasanton, TX 78064, USA
#
# The latitude is 32.2 ;the longitude is -96.9;the address is 210 L R Campbell Rd, Italy, TX 76651, USA
#
# The latitude is 30.1 ;the longitude is -97.4;the address is 696 Shiloh Rd, Bastrop, TX 78602, USA
#
# The latitude is 30.2 ;the longitude is -95.5;the address is 2 Long Lake Pl, Spring, TX 77381, USA
#
# The latitude is 30.6 ;the longitude is -96.7;the address is 2795 Co Rd 332, Caldwell, TX 77836, USA
#
# The latitude is 26.5 ;the longitude is -94.8;the address is Gulf of Mexico
#
# The latitude is 29.9 ;the longitude is -97.7;the address is Texas 130 Frontage Rd, Lockhart, TX 78644, USA
#
# ...
#
# The latitude is 34.1 ;the longitude is -92.6;the address is Tram Trail, Carthage, AR 71725, USA
#
# The latitude is 33.4 ;the longitude is -93.2;the address is 1820 Columbia Rd 45, McNeil, AR 71752, USA
#
# The latitude is 33.2 ;the longitude is -95.4;the address is Unnamed Road, Saltillo, TX 75478, USA
#
# The latitude is 32.9 ;the longitude is -95.7;the address is 319 Rs County Rd 3346, Emory, TX 75440, USA
#
# The latitude is 32.5 ;the longitude is -96.3;the address is 10580 Horton Ln, Kaufman, TX 75142, USA
#
# The latitude is 33.3 ;the longitude is -92.3;the address is Bradley 141 Rd, Strong, AR 71765, USA
#
# The latitude is 34 ;the longitude is -92.5;the address is 41 Dallas 102, Carthage, AR 71725, USA
#
# The latitude is 32.7 ;the longitude is -95.9;the address is Co Rd 3505, Edgewood, TX 75117, USA
#
# The latitude is 33.8 ;the longitude is -91.3;the address is 2543 AR-138, Tillar, AR 71670, USA
#
# The latitude is 31.8 ;the longitude is -96.8;the address is Hubbard, TX 76648, USA
#
# The latitude is 33.6 ;the longitude is -92.8;the address is 426 Ouachita Rd 44, Camden, AR 71701, USA
#
# The latitude is 42.7 ;the longitude is -96.1;the address is 24487 Noble Ave, Le Mars, IA 51031, USA
#
# The latitude is 41.3 ;the longitude is -96.5;the address is 2076 Co Rd 11, Mead, NE 68041, USA
#
# The latitude is 32.6 ;the longitude is -96.2;the address is 3022 Co Rd 101, Kaufman, TX 75142, USA
#
# The latitude is 33 ;the longitude is -95.5;the address is 786 FM2948, Como, TX 75431, USA
#
# The latitude is 33.5 ;the longitude is -93;the address is Ouachita Rd 87, Stephens, AR 71764, USA
#
# The latitude is 33.3 ;the longitude is -93.3;the address is 11 Columbia Rd 78, Waldo, AR 71770, USA
#
# The latitude is 33.1 ;the longitude is -93.9;the address is US-71, Bradley, AR 71826, USA
#
# The latitude is 33.7 ;the longitude is -91.3;the address is Clayton Township, AR, USA
#
# The latitude is 33.1 ;the longitude is -92.1;the address is Egypt Township, AR, USA
#
# The latitude is 34.1 ;the longitude is -90.3;the address is Corbin Rd, Lambert, MS 38643, USA
#
# The latitude is 34 ;the longitude is -90.8;the address is Unnamed Road, Shelby, MS 38774, USA
#
# The latitude is 33.9 ;the longitude is -90.7;the address is Unnamed Road, Mound Bayou, MS 38762, USA
#
# The latitude is 34 ;the longitude is -90.3;the address is Unnamed Road, Tutwiler, MS 38963, USA
#
# The latitude is 32.9 ;the longitude is -91.3;the address is 4, LA, USA
#
# The latitude is 34.1 ;the longitude is -90.5;the address is Green Estate Rd, Clarksdale, MS 38614, USA
#
# The latitude is 33.7 ;the longitude is -91.2;the address is Catfish Rd, Benoit, MS 38725, USA
#
# The latitude is 33.2 ;the longitude is -91.6;the address is Co Rd 69, Parkdale, AR 71661, USA
#
# The latitude is 34.2 ;the longitude is -90.2;the address is Eason Rd, Lambert, MS 38643, USA
#
# The latitude is 34 ;the longitude is -90.5;the address is Dogwalk Rd, Tutwiler, MS 38963, USA
#
# The latitude is 32.8 ;the longitude is -91.5;the address is 3342 LA-2, Oak Grove, LA 71263, USA
#
# The latitude is 34 ;the longitude is -90.2;the address is Sheley Rd, Tutwiler, MS 38963, USA
#
# The latitude is 33.8 ;the longitude is -91.1;the address is Franklin Township, AR, USA
#
# The latitude is 33.6 ;the longitude is -91.4;the address is 1749 Masonville Rd, McGehee, AR 71654, USA
#
# The latitude is 33.9 ;the longitude is -90.9;the address is Unnamed Road, Gunnison, MS 38746, USA
#
# The latitude is 33.9 ;the longitude is -90.5;the address is US-49W, Tutwiler, MS 38963, USA
#
# The latitude is 32.7 ;the longitude is -91.6;the address is Tracey Frisbee Rd, Pioneer, LA 71266, USA
#
# The latitude is 34 ;the longitude is -90.6;the address is Unnamed Road, Clarksdale, MS 38614, USA
#
# The latitude is 34 ;the longitude is -90.7;the address is Burroughs Rd, Shelby, MS 38774, USA
#
# The latitude is 34.2 ;the longitude is -90.3;the address is 1869 Caffey Ave, Lambert, MS 38643, USA
#
# The latitude is 33.7 ;the longitude is -91.1;the address is Rim Rd, Watson, AR 71674, USA
#
# The latitude is 33.1 ;the longitude is -91.8;the address is Co Rd 99, Hamburg, AR 71646, USA
#
# The latitude is 33.9 ;the longitude is -90.8;the address is Henry Hall Rd, Mound Bayou, MS 38762, USA
#
# The latitude is 43.1 ;the longitude is -91.6;the address is 189 US-52, Postville, IA 52162, USA
#
# The latitude is 43.2 ;the longitude is -91;the address is 56956 Swatek Ridge Rd, Steuben, WI 54657, USA
#
# The latitude is 43.2 ;the longitude is -91.1;the address is 25207 Varo Ln, Eastman, WI 54626, USA
#
# The latitude is 40.9 ;the longitude is -89.8;the address is 12823 W Chippe Dr, Princeville, IL 61559, USA
#
# The latitude is 43.3 ;the longitude is -91.5;the address is 619 Van Buren Dr, Waukon, IA 52172, USA
#
# The latitude is 43.2 ;the longitude is -92.1;the address is 1089 Windsor Ave, Waucoma, IA 52171, USA
#
# The latitude is 43.2 ;the longitude is -90.8;the address is 46720 Maple Ridge Rd, Boscobel, WI 53805, USA
#
# The latitude is 43.2 ;the longitude is -90.9;the address is 51645 County Road E, Steuben, WI 54657, USA
#
# The latitude is 43.2 ;the longitude is -90.7;the address is Badger Rd, Boscobel, WI 53805, USA
#
# The latitude is 43.3 ;the longitude is -91.7;the address is 2630 155th Ave, Decorah, IA 52101, USA
#
# The latitude is 43.3 ;the longitude is -91.4;the address is 1146 Iron Mine Dr, Waukon, IA 52172, USA
#
# The latitude is 40.9 ;the longitude is -89.7;the address is 6852 Co Hwy 2, Princeville, IL 61559, USA
#
# The latitude is 37.6 ;the longitude is -88.9;the address is 309 Egyptian Hills Dr, Creal Springs, IL 62922, USA
#
# The latitude is 39 ;the longitude is -96.1;the address is Alma Ln, Paxico, KS 66526, USA
#
# The latitude is 41 ;the longitude is -89.2;the address is 2278 County Rd 500 N, Toluca, IL 61369, USA
#
# The latitude is 41 ;the longitude is -88.3;the address is 25526 N 3300 E Rd, Cabery, IL 60919, USA
#
# The latitude is 41 ;the longitude is -87.7;the address is 3398 N 2280 East Rd, St Anne, IL 60964, USA
#
# The latitude is 34 ;the longitude is -100.1;the address is Unnamed Road, Paducah, TX 79248, USA
#
# The latitude is 38 ;the longitude is -97.1;the address is 14147 NW 120th St, Whitewater, KS 67154, USA
#
# The latitude is 37.8 ;the longitude is -88;the address is 16098 River Rd, Mt Vernon, IN 47620, USA
#
# The latitude is 37.8 ;the longitude is -88.1;the address is Round Pond Rd, Shawneetown, IL 62984, USA
#
# The latitude is 33.9 ;the longitude is -100.5;the address is Unnamed Road, Paducah, TX 79248, USA
#
# The latitude is 41 ;the longitude is -89.1;the address is 2829 County Road 500 North, Toluca, IL 61369, USA
#
# The latitude is 37.6 ;the longitude is -88.6;the address is 1897 Tom Dick Hill Rd, Stonefort, IL 62987, USA
#
# The latitude is 41 ;the longitude is -87.9;the address is 1209 E 3400 North Rd, Chebanse, IL 60922, USA
#
# The latitude is 37.6 ;the longitude is -89;the address is I-57, Marion, IL 62959, USA
#
# The latitude is 38.3 ;the longitude is -96.1;the address is 1481 Rd 100, Hartford, KS 66854, USA
#
# The latitude is 33.9 ;the longitude is -100.2;the address is Ranch Rd 3102, Paducah, TX 79248, USA
#
# The latitude is 38.3 ;the longitude is -96.2;the address is 949 Rd 100, Emporia, KS 66801, USA
#
# The latitude is 33.9 ;the longitude is -100.3;the address is Paducah, TX 79248, USA
#
# The latitude is 37.6 ;the longitude is -88.8;the address is Burnside Precinct, IL, USA
#
# The latitude is 37.5 ;the longitude is -88.6;the address is 211 Washington St, Eddyville, IL 62928, USA
#
# The latitude is 39.6 ;the longitude is -96;the address is 1365 16th Rd, Soldier, KS 66540, USA
#
# The latitude is 38.1 ;the longitude is -97;the address is 2139 20th St, Burns, KS 66840, USA
#
# The latitude is 33.9 ;the longitude is -100.1;the address is Unnamed Road, Paducah, TX 79248, USA
#
# The latitude is 39.6 ;the longitude is -96.4;the address is Cyclone Ln, Frankfort, KS 66427, USA
#
# The latitude is 36.9 ;the longitude is -94.4;the address is 11060 Kingfisher Dr, Neosho, MO 64850, USA
#
# The latitude is 38.3 ;the longitude is -96;the address is 2029 Rd 100, Hartford, KS 66854, USA
#
# The latitude is 41 ;the longitude is -88.1;the address is 12433 W 8000S Rd, Herscher, IL 60941, USA
# The latitude is 41 ;the longitude is -88.4;the address is 25505 N 2800 E Rd, Emington, IL 60934, USA
#
# The latitude is 37.9 ;the longitude is -97;the address is River Valley Rd, Towanda, KS 67144, USA
#
# The latitude is 38.2 ;the longitude is -96;the address is 2077 Rd 30, Hartford, KS 66854, USA
#
# The latitude is 41 ;the longitude is -89.4;the address is 500 N Rd, Lacon, IL 61540, USA
#
# The latitude is 38.3 ;the longitude is -96.6;the address is Den Creek Rd, Cottonwood Falls, KS 66845, USA
#
# The latitude is 38.3 ;the longitude is -96.5;the address is Unnamed Road, Cottonwood Falls, KS 66845, USA
#
# The latitude is 38 ;the longitude is -97.7;the address is 23449 SW 36th, Burrton, KS 67020, USA
#
# The latitude is 39.6 ;the longitude is -96.1;the address is Unnamed Road, Centralia, KS 66415, USA
#
# The latitude is 41 ;the longitude is -89;the address is 841 N 5th Rd, Rutland, IL 61358, USA
#
# The latitude is 41 ;the longitude is -88.2;the address is 614 Co Hwy 23, Cabery, IL 60919, USA
#
# The latitude is 41 ;the longitude is -88.8;the address is 6533 E 2550 N Rd, Streator, IL 61364, USA
#
# The latitude is 41 ;the longitude is -88.5;the address is 22450 E 2600 N Rd, Odell, IL 60460, USA
#
# The latitude is 39 ;the longitude is -96;the address is 27944 Sunnyside Rd, Maple Hill, KS 66507, USA
#
# The latitude is 41.1 ;the longitude is -88.7;the address is 32629 IL-18, Streator, IL 61364, USA
#
# The latitude is 37.6 ;the longitude is -88.7;the address is 235 Bynum Rd, Stonefort, IL 62987, USA
#
# The latitude is 39.1 ;the longitude is -95.9;the address is NW 31st St, Silver Lake, KS 66539, USA
#
# The latitude is 38.1 ;the longitude is -97.1;the address is 184 Old Mill Rd, Peabody, KS 66866, USA
#
# The latitude is 41 ;the longitude is -88;the address is 717 County Rd 3400 N, Chebanse, IL 60922, USA
#
# The latitude is 35.3 ;the longitude is -99.3;the address is Unnamed Road, Canute, OK 73626, USA
#
# The latitude is 38.3 ;the longitude is -96.8;the address is Unnamed Road, Cedar Point, KS 66843, USA
#
# The latitude is 38.1 ;the longitude is -97.2;the address is 9105 NE 48th St, Walton, KS 67151, USA
#
# The latitude is 38.1 ;the longitude is -96.9;the address is 20th St, Burns, KS 66840, USA
#
# The latitude is 38.2 ;the longitude is -96.8;the address is 90 Rd, Cedar Point, KS 66843, USA
#
# The latitude is 38.4 ;the longitude is -96.6;the address is US-50, Strong City, KS 66869, USA
#
# The latitude is 38.1 ;the longitude is -97.5;the address is 3800-4305 N Hertzler Rd, Halstead, KS 67056, USA
#
# The latitude is 38.3 ;the longitude is -97;the address is Timber Rd, Marion, KS 66861, USA
#
# The latitude is 38.3 ;the longitude is -96.7;the address is Cottonwood, KS, USA
#
# The latitude is 38.1 ;the longitude is -97.4;the address is NW 48th, Newton, KS 67114, USA
#
# The latitude is 38.3 ;the longitude is -96.9;the address is 160th St, Florence, KS 66851, USA
#
# The latitude is 38.4 ;the longitude is -96.1;the address is 1600 Rd R, Emporia, KS 66801, USA
#
# The latitude is 38.2 ;the longitude is -97.4;the address is 2839 Arrowhead Rd, Moundridge, KS 67107, USA
#
# The latitude is 35.5 ;the longitude is -99;the address is 2900 Reilly Rd, Clinton, OK 73601, USA
#
# The latitude is 35.4 ;the longitude is -99.1;the address is N2183 Rd, Foss, OK 73647, USA
#
# The latitude is 38.2 ;the longitude is -96.9;the address is 90th St, Florence, KS 66851, USA
#
# The latitude is 38.5 ;the longitude is -96.1;the address is 2370 Burlingame Rd, Emporia, KS 66801, USA
#
# The latitude is 35.4 ;the longitude is -99.2;the address is N2120 Rd, Foss, OK 73647, USA
#
# The latitude is 38.2 ;the longitude is -97;the address is Turkey Creek Rd, Peabody, KS 66866, USA
#
# The latitude is 38.5 ;the longitude is -96.6;the address is Diamond Creek, KS, USA
#
# The latitude is 38.2 ;the longitude is -97.3;the address is Diamond Rd, Newton, KS 67114, USA
#
# The latitude is 36.1 ;the longitude is -90.7;the address is 19 Gr 244 Rd, Beech Grove, AR 72412, USA
#
# The latitude is 36.1 ;the longitude is -91.2;the address is 3015 AR-117, Black Rock Township, AR, USA
#
# The latitude is 42 ;the longitude is -123.2;the address is 1035 Rd, Seiad Valley, CA 96086, USA
#
# The latitude is 31.1 ;the longitude is -86.2;the address is 8115 Eulon Mills Rd, Florala, AL 36442, USA
#
# The latitude is 30.9 ;the longitude is -85.4;the address is 4583 Railroad Ave, Cottondale, FL 32431, USA
#
# The latitude is 26.8 ;the longitude is -82;the address is 27600 Zemel Rd, Punta Gorda, FL 33955, USA
#
# The latitude is 31.1 ;the longitude is -86.3;the address is Big Martin Rd, Florala, AL 36442, USA
#
# The latitude is 27.7 ;the longitude is -79.1;the address is Atlantic Ocean
#
# The latitude is 28.5 ;the longitude is -81;the address is 3302 Taylor Creek Rd, Christmas, FL 32709, USA
#
# The latitude is 28.1 ;the longitude is -79.1;the address is Atlantic Ocean
#
# The latitude is 28.2 ;the longitude is -80.3;the address is United States
#
# The latitude is 28.2 ;the longitude is -80.4;the address is United States
#
# The latitude is 28.2 ;the longitude is -79.5;the address is Atlantic Ocean
#
# The latitude is 27.9 ;the longitude is -79.6;the address is Atlantic Ocean
#
# The latitude is 28.4 ;the longitude is -80.6;the address is 8910 Coquina Ln, Cape Canaveral, FL 32920, USA
#
# The latitude is 28.5 ;the longitude is -80.8;the address is Tico Rd, Titusville, FL 32780, USA
#
# The latitude is 28.8 ;the longitude is -78.8;the address is Atlantic Ocean
#
# The latitude is 27.2 ;the longitude is -78.7;the address is Atlantic Ocean
#
# The latitude is 28.4 ;the longitude is -80.4;the address is United States
#
# The latitude is 27.8 ;the longitude is -79.7;the address is Atlantic Ocean
#
# The latitude is 27.6 ;the longitude is -79.5;the address is Atlantic Ocean
#
# The latitude is 28.4 ;the longitude is -81.3;the address is Heintzelman Blvd, Orlando, FL 32827, USA
#
# The latitude is 27.8 ;the longitude is -79.3;the address is Atlantic Ocean
#
# The latitude is 28.4 ;the longitude is -80.5;the address is United States
#
# The latitude is 28.5 ;the longitude is -81.3;the address is 6207 Pershing Ave, Orlando, FL 32822, USA
#
# The latitude is 27.2 ;the longitude is -77.6;the address is Atlantic Ocean
#
# The latitude is 27.9 ;the longitude is -79.8;the address is Atlantic Ocean
#
# The latitude is 26.8 ;the longitude is -77.4;the address is The Bahamas
#
# The latitude is 27.6 ;the longitude is -79.8;the address is Atlantic Ocean
#
# The latitude is 28.4 ;the longitude is -81;the address is Cocoa Water Plant Rd, Florida, USA
#
# The latitude is 28.3 ;the longitude is -81.4;the address is 900 Lawrence Silas Blvd, Kissimmee, FL 34744, USA
#
# The latitude is 42.2 ;the longitude is -123.1;the address is Negro Ben Rd, Jacksonville, OR 97530, USA
#
# The latitude is 27.8 ;the longitude is -78.5;the address is Atlantic Ocean
#
# The latitude is 27.4 ;the longitude is -78;the address is Atlantic Ocean
#
# The latitude is 27.6 ;the longitude is -79.4;the address is Atlantic Ocean
#
# The latitude is 27.9 ;the longitude is -79.7;the address is Atlantic Ocean
#
# The latitude is 27.8 ;the longitude is -78.4;the address is Atlantic Ocean
#
# The latitude is 28 ;the longitude is -80.1;the address is United States
#
# The latitude is 28.5 ;the longitude is -80.5;the address is Brevard County, FL, USA
#
# The latitude is 28.5 ;the longitude is -80.9;the address is Florida Trail, Titusville, FL 32780, USA
#
# The latitude is 28.1 ;the longitude is -79.2;the address is Atlantic Ocean
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-40096ab6ae69> in <module>
#       9         url="https://maps.googleapis.com/maps/api/geocode/json?latlng="+lat+","+lon+"&key="+api_key
#      10         info=requests.get(url).json()
# ---> 11         address=info['results'][0]["formatted_address"]
#      12         print ("The latitude is "+lat+ " ;the longitude is "+ lon+ ";the address is "+ address+"\n")
#      13         file1.write(lon+"\t"+lat+"\t"+address+"\n")
#
# IndexError: list index out of range

# %%
info
# Out:
# {'plus_code': {'global_code': '77V434X2+X2'},
#  'results': [],
#  'status': 'ZERO_RESULTS'}

# %%
# Read location information
locations=pd.read_csv("locations.csv",header=None)
locations.columns=['lng','lat','address']

# check the dimension of locations
print ("The dimension is:", locations.shape)
# Out:
# The dimension is: (1511, 3)

# %%
locations.head(3)
# Out:
#     lng   lat                       address
# 0 -96.2  31.5  Rch Rd, Donie, TX 75838, USA
# 1 -79.1  31.5                Atlantic Ocean
# 2 -78.9  30.5                Atlantic Ocean

# %%
# Deleted the rows where address is equal to "United States"
locs=locations[locations.address!='United States']
print ("The dimension is:", locs.shape)
# Out:
# The dimension is: (1508, 3)

# %%
# Merge the two data sets along with latitude and longitude
tmp=pd.merge(locs,data,how='left',left_on=['lat','lng'],right_on=['Latitude','Longitude']) 
# tmp.astype(float)
# Check the dimension of the new dataset
print ("The dimension is ", tmp.shape)
# Out:
# The dimension is  (56691, 12)

# %%
tmp.head()
# Out:
#     lng   lat                       address       center_point   Day    Year  \
# 0 -96.2  31.5  Rch Rd, Donie, TX 75838, USA  POINT(-96.2 31.5)   2.0  1992.0
# 1 -96.2  31.5  Rch Rd, Donie, TX 75838, USA  POINT(-96.2 31.5)  22.0  1992.0
# 2 -96.2  31.5  Rch Rd, Donie, TX 75838, USA  POINT(-96.2 31.5)   3.0  1992.0
# 3 -96.2  31.5  Rch Rd, Donie, TX 75838, USA  POINT(-96.2 31.5)  16.0  1992.0
# 4 -96.2  31.5  Rch Rd, Donie, TX 75838, USA  POINT(-96.2 31.5)   9.0  1992.0
#
#    Month  Longitude  Latitude  LongitudeR  LatitudeR  Strikes
# 0    1.0      -96.2      31.5       -96.0       32.0       23
# 1    6.0      -96.2      31.5       -96.0       32.0       31
# 2    9.0      -96.2      31.5       -96.0       32.0       56
# 3   10.0      -96.2      31.5       -96.0       32.0       29
# 4    3.0      -96.2      31.5       -96.0       32.0        1

# %%
tmp.dtypes
# Out:
# lng             float64
# lat             float64
# address          object
# center_point     object
# Day             float64
# Year            float64
# Month           float64
# Longitude       float64
# Latitude        float64
# LongitudeR      float64
# LatitudeR       float64
# Strikes           int64
# dtype: object

# %%
# Divide into seasons
spring=tmp[(tmp.Day>='1992-01-01') & (tmp.Day<'1992-04-01')]
summer=tmp[(tmp.Day>='1992-04-01') & (tmp.Day<'1992-07-01')]
fall=tmp[(tmp.Day>='1992-07-01') & (tmp.Day<'1992-10-01')]
winter=tmp[(tmp.Day>='1992-10-01') & (tmp.Day<='1992-12-31')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-b964df7fdcca> in <module>
#       1 # Divide into seasons
# ----> 2 spring=tmp[(tmp.Day>='1992-01-01') & (tmp.Day<'1992-04-01')]
#       3 summer=tmp[(tmp.Day>='1992-04-01') & (tmp.Day<'1992-07-01')]
#       4 fall=tmp[(tmp.Day>='1992-07-01') & (tmp.Day<'1992-10-01')]
#       5 winter=tmp[(tmp.Day>='1992-10-01') & (tmp.Day<='1992-12-31')]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1649                     result = method(y)
#    1650                 if result is NotImplemented:
# -> 1651                     return invalid_comparison(x, y, op)
#    1652             else:
#    1653                 result = op(x, y)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops.py in invalid_comparison(left, right, op)
#    1056     else:
#    1057         raise TypeError("Invalid comparison between dtype={dtype} and {typ}"
# -> 1058                         .format(dtype=left.dtype, typ=type(right).__name__))
#    1059     return res_values
#    1060
#
# TypeError: Invalid comparison between dtype=float64 and str

# %% [markdown]
# # Heatmap of Strikes

# %%
# Configure gmaps with API key
gmaps.configure(api_key="AIzaSyAEMyR2Sr5a_ZsOsOQQTeuAJzV01suq1sk")

# %%
# Store 'Lat' and 'Lng' into  locations 
locations_spring = tmp[["lat", "lng"]].astype(float)

# Convert Strikes to float and store
# HINT: be sure to handle NaN values
strike_spring =tmp["Strikes"].astype(float)

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations_spring, weights=strike_spring, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = .5)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = 1

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Store 'Lat' and 'Lng' into  locations 
locations_summer = summer[["lat", "lng"]].astype(float)

# Convert Strikes to float and store
# HINT: be sure to handle NaN values
strike_summer =summer["number_of_strikes"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-7865f87c24b0> in <module>
#       1 # Store 'Lat' and 'Lng' into  locations
# ----> 2 locations_summer = summer[["lat", "lng"]].astype(float)
#       3
#       4 # Convert Strikes to float and store
#       5 # HINT: be sure to handle NaN values
#
# NameError: name 'summer' is not defined

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations_summer, weights=strike_summer, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = 1

fig.add_layer(heat_layer)

fig
