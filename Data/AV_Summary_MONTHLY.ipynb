# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
newList = []
filename = []

path = os.path.join('.')

with os.scandir(path) as it:
    for entry in it:
        if entry.name.endswith(".csv") and entry.is_file():
            filename.append(entry.name)

# filename = ['1992_mod.csv','1993_mod.csv','1994_mod.csv']

for file in filename:
    data = pd.read_csv(file,encoding='utf-8')
    data.columns = ['day', 'number_of_strikes', 'center_point', 'Day', 'Year', 'Month','Longitude', 'Latitude', 'LongitudeR', 'LatitudeR', 'Strikes']
    data.drop(columns = ['day','number_of_strikes','center_point',],axis=1,inplace=True)
    newList.append(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-664863401a4a> in <module>
#      19 for file in filename:
#      20     data = pd.read_csv(file,encoding='utf-8')
# ---> 21     data.columns = ['day', 'number_of_strikes', 'center_point', 'Day', 'Year', 'Month','Longitude', 'Latitude', 'LongitudeR', 'LatitudeR', 'Strikes']
#      22     data.drop(columns = ['day','number_of_strikes','center_point',],axis=1,inplace=True)
#      23     newList.append(data)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 11 elements

# %%
df = pd.concat(newList)
df.shape
# Out:
# (94527458, 8)

# %%
modified=[]
new=[]
sum1=[]
# z=0
# for x in range((len(filename))-0):
#     thisOne=df[z][x]
# #     print(thisOne)
modified=df.groupby(['Year','Month'])
m1=modified['Strikes'].sum()
byMonth=pd.DataFrame(m1)
#     byYear.reset_index()
sum1.append(byMonth)
# m1
# m2=pd.DataFrame(m1) # m2.columns=['SAJNPIDNPIANB']

# data.groupby('Month').sum()

# byMonth=pd.DataFrame().sum
# byYear=pd.DataFrame(byMonth.sum())
# modified.reset_indexmSum

# %%
df_test=pd.concat(sum1)

# %%
df_test.reset_index()
# Out:
#        Year  Month   Strikes
# 0    1987.0    1.0     23044
# 1    1987.0    2.0     61020
# 2    1987.0    3.0    117877
# 3    1987.0    4.0    157890
# 4    1987.0    5.0    700910
# 5    1987.0    6.0   1064166
# 6    1987.0    7.0   2077619
# 7    1987.0    8.0   2001899
# 8    1987.0    9.0    869833
# 9    1987.0   10.0    105627
# 10   1987.0   11.0    155290
# 11   1987.0   12.0     43661
# 12   1988.0    1.0     24228
# 13   1988.0    2.0     27924
# 14   1988.0    3.0    149671
# 15   1988.0    4.0    213056
# 16   1988.0    5.0    743200
# 17   1988.0    6.0   1698011
# 18   1988.0    7.0   2511155
# 19   1988.0    8.0   2734319
# 20   1988.0    9.0    528825
# 21   1988.0   10.0    274616
# 22   1988.0   11.0    223117
# 23   1988.0   12.0     22318
# 24   1989.0    1.0     45991
# 25   1989.0    2.0     54969
# 26   1989.0    3.0    443395
# 27   1989.0    4.0    706368
# 28   1989.0    5.0   1476731
# 29   1989.0    6.0   2322187
# ..      ...    ...       ...
# 359  2016.0   12.0    316450
# 360  2017.0    1.0    690474
# 361  2017.0    2.0    591948
# 362  2017.0    3.0   1161857
# 363  2017.0    4.0   3819075
# 364  2017.0    5.0   4740613
# 365  2017.0    6.0   4988897
# 366  2017.0    7.0   8674181
# 367  2017.0    8.0   6021702
# 368  2017.0    9.0   2581578
# 369  2017.0   10.0   1089571
# 370  2017.0   11.0    440341
# 371  2017.0   12.0    294958
# 372  2018.0    1.0    856653
# 373  2018.0    2.0   2071315
# 374  2018.0    3.0   5180066
# 375  2018.0    4.0   8790277
# 376  2018.0    5.0  29245541
# 377  2018.0    6.0  52087148
# 378  2018.0    7.0  52541964
# 379  2018.0    8.0  22555828
# 380  2018.0    9.0   3268893
# 381  2018.0   10.0   1093962
# 382  2018.0   11.0    409263
# 383  2018.0   12.0    312097
# 384  2019.0    3.0    420521
# 385  2019.0    4.0   1580654
# 386  2019.0    5.0   3435471
# 387  2019.0    6.0   4408619
# 388  2019.0    7.0   4572279
#
# [389 rows x 3 columns]

# %%
df_test.to_csv("Strikes_per_Month.csv" , index=True, header=True)

# %%
sum1
# Out:
# [          Strikes
#  Year
#  1987.0    7378836
#  1988.0    9150440
#  1989.0   14245186
#  1990.0   15839052
#  1991.0   16900934
#  1992.0   16371876
#  1993.0   24206929
#  1994.0   25094010
#  1995.0   22763540
#  1996.0   26190094
#  1997.0   26986915
#  1998.0   28802221
#  1999.0   27758681
#  2000.0   26276135
#  2001.0   25470095
#  2002.0   29916767
#  2003.0   39092327
#  2004.0   40023951
#  2005.0   38168699
#  2006.0   33292382
#  2007.0   30529064
#  2008.0   29790934
#  2009.0   30100585
#  2010.0   29068965
#  2011.0   31392058
#  2012.0   28807552
#  2013.0   27600898
#  2014.0   34919173
#  2015.0   37894191
#  2016.0   41582229
#  2017.0   35095195
#  2018.0  178413007
#  2019.0   14417544]

# %%
byMonth=pd.DataFrame(data.groupby('Month')).sum
byYear=pd.DataFrame(byMonth.sum())

# %%
byMonth

# %%
byYear.reset_index()

# %%
new=modified['Strikes'].sum()

# %%
df_test.to_csv("Strikes_per_Year.csv", 'a' index=False, header=False)

# %%
data.columns['Day']=data.columns['Year']
# data['Year']=month.astype(float) data['Month']
# data['Month']=day.astype(float)  data['Day']
# data['Latitude']=latitude.astype(float)
# data['Longitude']=longitude.astype(float)
# data['LatitudeR']=latitude.astype(float).round(0)
# data['LongitudeR']=longitude.astype(float).round(0)
# data['Strikes']=strikes

# %%
data.to_csv("1989_Summary.csv", index=False, header=True) 
data.head()
# print (data.dtypes)

# %%
data = None

# %%
gDF=data.groupby('Month')
gDF['Strikes'].sum()
# data.head()

# %%
data.to_csv("1988_strikes_per_month.csv", index=False, header=True)

# %%
grouped_df=data.groupby('LatitudeR')
Lat=grouped_df['LatitudeR'].sum()/grouped_df['LatitudeR'].count()
Gstrikes=grouped_df['Strikes'].sum()

# %%
plt.scatter(Lat, Gstrikes, marker="o", facecolors="b", label="Suburban",edgecolors="black", s=Gstrikes/1000, alpha=0.5)
plt.title("Latitude vs. number_of_strikes",fontsize=14)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("number_of_strikes",fontsize=12)
plt.grid()
plt.savefig("LatStrikes.png")

# %%
grouped_df=data.groupby('LongitudeR')
Lon=grouped_df['LongitudeR'].sum()/grouped_df['LongitudeR'].count()
Gstrikes=grouped_df['Strikes'].sum()

# %%
plt.scatter(Lon, Gstrikes, marker="o", facecolors="b", label="Suburban",edgecolors="black", s=Gstrikes/1000, alpha=0.5)
plt.title("longitude vs. number_of_strikes",fontsize=14)
plt.xlabel("longitude",fontsize=12)
plt.ylabel("number_of_strikes",fontsize=12)
plt.grid()
plt.savefig("LonStrikes.png")

# %%
grouped_df=data.groupby('Month')
Month=grouped_df['Month'].sum()/grouped_df['Month'].count()
Gstrikes=grouped_df['Strikes'].sum()

# %%
plt.scatter(Month, Gstrikes, marker="o", facecolors="b", label="Suburban",edgecolors="black", s=Gstrikes/1000, alpha=0.5)
plt.title("Month vs. number_of_strikes",fontsize=14)
plt.xlabel("Month",fontsize=12)
plt.ylabel("number_of_strikes",fontsize=12)
plt.grid()
plt.savefig("MonthStrikes.png")
