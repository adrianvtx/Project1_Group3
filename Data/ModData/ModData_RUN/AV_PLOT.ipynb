# %%
import numpy as np
import pandas as pd
# from scipy import # https://docs.scipy.org/doc/scipy/reference/
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

newList = []
filename = []

path = os.path.join('.')

with os.scandir(path) as it:
    for entry in it:
        if entry.name.endswith(".csv") and entry.is_file():
            filename.append(entry.name)

# filename = ['1992_mod.csv','1993_mod.csv','1994_mod.csv']

for file in filename:
    data = pd.read_csv(file)
#     newList.append(data)
    # Load the dataset
    
# df = pd.concat(newList)
# df.shape

# %%
data=data.round()
data.values
# Out:
# array([[1.987000e+03, 1.000000e+00, 2.304400e+04],
#        [1.987000e+03, 2.000000e+00, 6.102000e+04],
#        [1.987000e+03, 3.000000e+00, 1.178770e+05],
#        ...,
#        [2.019000e+03, 5.000000e+00, 3.435471e+06],
#        [2.019000e+03, 6.000000e+00, 4.408619e+06],
#        [2.019000e+03, 7.000000e+00, 4.572279e+06]])

# %%
sns.pairplot(data)

# %%
# lat=data['Latitude']
# lon=data['Longitude']
mth=data['Month']
yer=data['Year']
sks=data['Strikes']/1000000

sns.scatterplot("Year",sks,data=data)
plt.xlim(1986,2020)
plt.ylim(0,12)
# Out:
# (0, 12)

# %%
data.head()
# Out:
#      Year  Month  Strikes
# 0  1987.0    1.0    23044
# 1  1987.0    2.0    61020
# 2  1987.0    3.0   117877
# 3  1987.0    4.0   157890
# 4  1987.0    5.0   700910

# %%
sns.set()
data=data.groupby
g = sns.FacetGrid(data, col="Month")
g.map(plt.hist, "Strikes");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ab10bb6c6045> in <module>
#       1 sns.set()
#       2 data=data.groupby
# ----> 3 g = sns.FacetGrid(data, col="Month")
#       4 g.map(plt.hist, "Strikes");
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     248             col_names = []
#     249         else:
# --> 250             col_names = utils.categorical_order(data[col], col_order)
#     251
#     252         # Additional dict of kwarg -> list of values for mapping the hue var
#
# TypeError: 'method' object is not subscriptable

# %%
# sns.set(style="whitegrid")
# sns.scatterplot(lat,lon,hue=yer,size=sks,sizes=(1,100))


sns.set
# Plot sepal with as a function of sepal_length across days
g = sns.lmplot(x=lat, y=lon, data=data, hue=sks, col=yer, row=mth)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Sepal length (mm)", "Sepal width (mm)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-265d1b49cb77> in <module>
#       5 sns.set
#       6 # Plot sepal with as a function of sepal_length across days
# ----> 7 g = sns.lmplot(x=lat, y=lon, data=data, hue=sks, col=yer, row=mth)
#       8
#       9 # Use more informative axis labels than are provided by default
#
# NameError: name 'lat' is not defined

# %%
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="distance", y="orbital_period",
                     hue="year", size="mass",
                     palette=cmap, sizes=(10, 200),
                     data=planets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-48f628c9ea73> in <module>
#       3                      hue="year", size="mass",
#       4                      palette=cmap, sizes=(10, 200),
# ----> 5                      data=planets)
#
# NameError: name 'planets' is not defined
